# %%
import os
import sys


sys.path.append(os.path.abspath(os.path.join('..')))
from utils import postgres, MLFlowManager

def query(sql, params=None):
    with postgres() as pg:
        return pg.query(sql, params)

# %%
sql_desc = "SELECT * FROM chembl_pic50_ml_ready"
df = query(sql_desc)

print(df.shape)
df.head()
# Out:
# /home/pkuszn/repos/WSzI/src/utils/pg_connector.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, self.conn, params=params) # type: ignore
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File ~/repos/WSzI/src/.venv/lib/python3.12/site-packages/pandas/io/sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# UndefinedTable: relation "chembl_pic50_ml_ready" does not exist
# LINE 1: SELECT * FROM chembl_pic50_ml_ready
#                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ...
